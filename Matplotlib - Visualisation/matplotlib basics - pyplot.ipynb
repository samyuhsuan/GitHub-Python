# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
salary = np.linspace(20000, 80000, 20)
rank = np.arange(1, 21)

# %%
year = np.arange(1989, 2009)

# %%
data = pd.DataFrame({"salary":salary, "rank":rank, "year":year})

# %%
plt.plot(rank, salary)
plt.axis()
plt.xlabel(year)
