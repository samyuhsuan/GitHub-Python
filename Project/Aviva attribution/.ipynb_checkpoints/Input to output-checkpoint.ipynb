# %%
import pandas as pd
import numpy as np
import glob

# %%
zo = pd.DataFrame()
for file in glob.glob("dbm*.csv"):
    df = pd.read_csv(file)
    zo = zo.append(df, ignore_index=True)

# %%
dbm = pd.DataFrame()
for file in glob.glob("att*.csv"):
    df = pd.read_csv(file, skipinitialspace=True, 
            usecols=["Insertion Order", "Insertion Order ID", "Line Item", "Line Item ID", "Revenue (Adv Currency)"])
    dbm = dbm.append(df, ignore_index=True)

# %%
IOIDmap = pd.read_csv("map.csv", usecols=["IOID", "Targeting"])

# %%
dbm.columns = ["IO", "IOID", "LI", "LIID", "Spend"]

# %%
dbm = dbm.drop(dbm.index[dbm.tail(5).index.values])
dbm = dbm.loc[dbm.LI.isnull() == False]

# %%
dbm.IOID = dbm.IOID.astype("int64")
dbm.LIID = dbm.LIID.astype("int64")

# %%
#pd.DataFrame(dbm.IOID.unique(), columns=["uniqueIOID"]).to_csv(
#    "D:\\Users\\ylin\\Desktop\\Aviva ATT output\\"+"uniqueIOID.csv", index=False)

# %%
dbm_ = pd.DataFrame(dbm.pivot_table(values="Spend", index=["IOID", "IO"], aggfunc=np.sum)).reset_index()

# %%
zo_ = pd.DataFrame(zo.pivot_table(values="zo_attr", index="dbm_insertion_order_id", aggfunc=np.sum)).reset_index()

# %%
zo_.columns = ["IOID", "zo_attr"]

# %%
data = dbm_.merge(zo_, on="IOID", how="left")

# %%
data = data.merge(IOIDmap, on="IOID", how="left")

# %%
data_ = data.pivot_table(values=["Spend", "zo_attr"], index="Targeting").reset_index()

# %%
data_["zoCPQ"] = data.Spend / data.zo_attr

# %%
data_.to_csv("D:\\Users\\ylin\\Desktop\\"+"latest CPQ.csv", index=False)

# %%
data
# Out:
#        IOID                                                 IO         Spend  \
# 0   2227377  O-GGF8_Aviva_UK_AD_2016_April_Car Insurance_Pr...   4841.783338
# 1   2227378  O-GGF8_Aviva_UK_AD_2016_April_Car Insurance_Re...  12252.067670
# 2   2293077  O-HFG9_Aviva_UK_AD_2016_May_Car Insurance_Pros...   8139.232561
# 3   2293078  O-HFG9_Aviva_UK_AD_2016_May_Car Insurance_Reta...  18479.739756
# 4   2352595  O-HZNC_Aviva_UK_AD_2016_June_Car Insurance_Pro...  10132.459632
# 5   2352596  O-HZNC_Aviva_UK_AD_2016_June_Car Insurance_Ret...  18796.065904
# 6   2428661  O-JSGV_Aviva_UK_AD_2016_July_Car Insurance_Pro...   5829.770529
# 7   2428662  O-JSGV_Aviva_UK_AD_2016_July_Car Insurance_Ret...  24732.960253
# 8   2488685  O-KF4B_Aviva_UK_AD_2016_August_Car Insurance_P...  14332.854346
# 9   2488686  O-KF4B_Aviva_UK_AD_2016_August_Car Insurance_R...  14913.894549
# 10  2559539  O-L2PP_2016_Aviva_UK_September_Car Insurance_P...  13680.094624
# 11  2564571  O-L2PP_2016_Aviva_UK_September_Car Insurance_R...  14752.660971
# 12  2637374  O-LVP9_2016_Aviva_Car Insurance_Non-Customers_...  12645.882917
# 13  2638741  O-LVP9_2016_Aviva_Car Insurance_Non-Customers_...  13501.238158
# 14  2646290  O-LVP9_2016_Aviva_Car Insurance_Existing Custo...    622.972982
# 15  2709277  O-ML40_2016_Aviva_Car Insurance_Non-Customers_...   8286.187486
# 16  2709279  O-ML40_2016_Aviva_Car Insurance_Existing Custo...   1018.189610
# 17  2712512  O-ML40_2016_Aviva_Car Insurance_Non-Customers_...  10976.656304
# 18  2806248  O-N4YG_2016_Aviva_Car Insurance_Existing Custo...   1024.875373
# 19  2806249  O-N4YG_2016_Aviva_Car Insurance_Non-Customers_...   1222.274236
# 20  2806250  O-N4YG_2016_Aviva_Car Insurance_Non-Customers_...   2470.462644
# 21  2814418  O-N4YG_2016_Aviva_Car Insurance_Non-Customers_...   1538.675383
# 22  2814419  O-N4YG_2016_Aviva_Car Insurance_Non-Customers_...   2197.169110
# 23  2814422  O-N4YG_2016_Aviva_Car Insurance_Non-Customers_...    959.319497
# 24  2814423  O-N4YG_2016_Aviva_Car Insurance_Non-Customers_...   2394.452433
# 25  2886944  O-NR27_2017_Aviva_Car Insurance_Existing Custo...   4047.407277
# 26  2886945  O-NR27_2017_Aviva_Car Insurance_Non-Customers_...   8000.071116
# 27  2886946  O-NR27_2017_Aviva_Car Insurance_Non-Customers_...  10725.902351
# 28  2959862  O-PLTW_2017_Aviva_Car Insurance_Existing Custo...   2996.078222
# 29  2959863  O-PLTW_2017_Aviva_Car Insurance_Non-Customers_...  10781.931804
# 30  2959864  O-PLTW_2017_Aviva_Car Insurance_Non-Customers_...  10852.488397
# 31  3054348  O-QR5R_2017_Aviva_Car Insurance_Non-Customers_...  11590.890030
# 32  3054349  O-QR5R_2017_Aviva_Car Insurance_Existing Custo...   2779.550460
# 33  3054350  O-QR5R_2017_Aviva_Car Insurance_Non-Customers_...  13357.983817
# 34  3191758  O-RK1W_2017_Aviva_Car Insurance_Non-Customers_...   9071.737430
# 35  3191759  O-RK1W_2017_Aviva_Car Insurance_Existing Custo...   3683.755949
# 36  3191760  O-RK1W_2017_Aviva_Car Insurance_Non-Customers_...    202.866468
# 37  3227263  O-RK1W_2017_Aviva_Car Insurance_Non-Customers_...  11262.056550
# 38  3323740  O-SC7K_2017_Aviva_Car Insurance_Existing Custo...    986.038596
# 39  3323741  O-SC7K_2017_Aviva_Car Insurance_Non-Customers_...   3430.907376
# 40  3323742  O-SC7K_2017_Aviva_Car Insurance_Non-Customers_...   3156.969862
#
#         zo_attr                 Targeting
# 0    920.547020               Prospecting
# 1   4129.332453  Remarketing non-existing
# 2   1305.569284               Prospecting
# 3   3060.435170  Remarketing non-existing
# 4   1590.505081               Prospecting
# 5   2622.865484  Remarketing non-existing
# 6    831.749619               Prospecting
# 7   2478.100918  Remarketing non-existing
# 8   1569.839513               Prospecting
# 9   2321.899846  Remarketing non-existing
# 10  1235.268348               Prospecting
# 11  1999.566990  Remarketing non-existing
# 12  1081.317965               Prospecting
# 13  1302.324470  Remarketing non-existing
# 14    90.373367      Remarketing existing
# 15   632.323330               Prospecting
# 16    84.412812      Remarketing existing
# 17  1059.073409  Remarketing non-existing
# 18    99.430596      Remarketing existing
# 19   106.327901               Prospecting
# 20   230.425128  Remarketing non-existing
# 21   181.800054               Prospecting
# 22   260.508563  Remarketing non-existing
# 23    94.542481               Prospecting
# 24   304.221773  Remarketing non-existing
# 25   288.732141      Remarketing existing
# 26   941.886385               Prospecting
# 27  1287.051514  Remarketing non-existing
# 28   439.610535      Remarketing existing
# 29  2070.744042               Prospecting
# 30  2374.296020  Remarketing non-existing
# 31  3735.661524  Remarketing non-existing
# 32   497.544343      Remarketing existing
# 33  2044.723204               Prospecting
# 34  1160.781220               Prospecting
# 35   368.464702      Remarketing existing
# 36    62.476275  Remarketing non-existing
# 37  2695.028950  Remarketing non-existing
# 38    36.700320      Remarketing existing
# 39   243.496209  Remarketing non-existing
# 40    61.621637               Prospecting
