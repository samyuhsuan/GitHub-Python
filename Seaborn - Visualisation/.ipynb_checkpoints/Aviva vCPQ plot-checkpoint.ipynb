# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
aviva = pd.read_csv("AvivaView.csv")

# %%
aviva.columns
# Out:
# Index(['Row Labels', 'Targeting', 'Recency', 'Sum of Viewability',
#        'Sum of Active View: Measurable Impressions',
#        'Sum of Active View: Viewable Impressions', 'Sum of Impressions',
#        'Sum of Quotes', 'Sum of Spend', 'Viewgroup'],
#       dtype='object')

# %%
aviva.columns = ['Key', 'Targeting', 'Recency', 'Viewability',
       'MeasurableImpressions',
       'ViewableImpressions', 'Impressions',
       'Quotes', 'Spend', 'Viewgroup']

# %%
aviva.tail(17)
# Out:
#                                                    Key    Targeting Recency  \
# 722  Start quote__O-CV5S_Aviva_UK_AD_2016_Jan_Car I...  Start quote     NaN
# 723  Start quote__O-CV5S_Aviva_UK_AD_2016_Jan_Car I...  Start quote     NaN
# 724                                               ____          NaN     NaN
# 725                                                NaN          NaN     NaN
# 726                                                NaN          NaN     NaN
# 727                                                NaN          NaN     NaN
# 728                                                NaN          NaN     NaN
# 729                                                NaN          NaN     NaN
# 730                                                NaN          NaN     NaN
# 731                                                NaN          NaN     NaN
# 732                                                NaN          NaN     NaN
# 733                                                NaN          NaN     NaN
# 734                                                NaN          NaN     NaN
# 735                                                NaN          NaN     NaN
# 736                                                NaN          NaN     NaN
# 737                                                NaN          NaN     NaN
# 738                                                NaN          NaN     NaN
#
#     Viewability  MeasurableImpressions  ViewableImpressions  Impressions  \
# 722     #DIV/0!                    0.0                  0.0          0.0
# 723     #DIV/0!                    0.0                  0.0          0.0
# 724     #DIV/0!                    NaN                  NaN          NaN
# 725         NaN                    NaN                  NaN          NaN
# 726         NaN                    NaN                  NaN          NaN
# 727         NaN                    NaN                  NaN          NaN
# 728         NaN                    NaN                  NaN          NaN
# 729         NaN                    NaN                  NaN          NaN
# 730         NaN                    NaN                  NaN          NaN
# 731         NaN                    NaN                  NaN          NaN
# 732         NaN                    NaN                  NaN          NaN
# 733         NaN                    NaN                  NaN          NaN
# 734         NaN                    NaN                  NaN          NaN
# 735         NaN                    NaN                  NaN          NaN
# 736         NaN                    NaN                  NaN          NaN
# 737         NaN                    NaN                  NaN          NaN
# 738         NaN                    NaN                  NaN          NaN
#
#      Quotes  Spend Viewgroup
# 722     2.0    0.0   #DIV/0!
# 723     1.0    0.0   #DIV/0!
# 724     NaN    NaN   #DIV/0!
# 725     NaN    NaN      -30%
# 726     NaN    NaN      -30%
# 727     NaN    NaN      -30%
# 728     NaN    NaN      -30%
# 729     NaN    NaN      -30%
# 730     NaN    NaN      -30%
# 731     NaN    NaN      -30%
# 732     NaN    NaN      -30%
# 733     NaN    NaN      -30%
# 734     NaN    NaN      -30%
# 735     NaN    NaN      -30%
# 736     NaN    NaN      -30%
# 737     NaN    NaN      -30%
# 738     NaN    NaN      -30%

# %%
aviva = aviva.drop(aviva.index[724:])

# %%
aviva.head()
# Out:
#                                                  Key     Targeting Recency  \
# 0  Car homepage__O-GGF8_Aviva_UK_AD_2016_April_Ca...  Car homepage     NaN
# 1  Car homepage__O-FZKM_Aviva_UK_AD_2016_Mar_Car ...  Car homepage     NaN
# 2  Car homepage__O-HZNC_Aviva_UK_AD_2016_June_Car...  Car homepage     NaN
# 3  Car homepage__O-F5QT_Aviva_UK_AD_2016_Feb_Car ...  Car homepage     NaN
# 4  Car homepage__O-HZNC_Aviva_UK_AD_2016_June_Car...  Car homepage     NaN
#
#    Viewability  MeasurableImpressions  ViewableImpressions  Impressions  \
# 0  0.838497755                 9133.0               7658.0       9253.0
# 1   0.83355128                10706.0               8924.0      10909.0
# 2  0.831478448                17701.0              14718.0      18293.0
# 3  0.823856649                17077.0              14069.0      17408.0
# 4  0.814862316                53020.0              43204.0      53829.0
#
#    Quotes       Spend Viewgroup
# 0     1.0   31.848713      70%+
# 1     1.0   38.151969      70%+
# 2     NaN   63.331883      70%+
# 3     4.0   66.937527      70%+
# 4    16.0  222.033123      70%+

# %%
aviva = aviva.drop(aviva.Key == "Grand Total")

# %%
aviva["CPM"] = aviva.Spend / aviva.Impressions * 1000
aviva["CPQ"] = aviva.Spend / aviva.Quotes
aviva["ViewQuotes"] = aviva.Quotes * (aviva.ViewableImpressions / aviva.MeasurableImpressions)
aviva["vCPQ"] = aviva.Spend / (aviva.Quotes * (aviva.ViewableImpressions / aviva.MeasurableImpressions))
aviva["Viewability"] = aviva.ViewableImpressions / aviva.MeasurableImpressions

# %%
aviva["Recency"][aviva["Recency"].isnull() == True] = "Others"

# %%
aviva["Viewgroup"] = 0
aviva["Viewgroup"][aviva.Viewability < 0.3999999] = 0.3
aviva["Viewgroup"][(aviva.Viewability < 0.4999999) & (aviva.Viewability > 0.4)] = 0.4
aviva["Viewgroup"][(aviva.Viewability < 0.5999999) & (aviva.Viewability > 0.5)] = 0.5
aviva["Viewgroup"][(aviva.Viewability < 0.6999999) & (aviva.Viewability > 0.6)] = 0.6
aviva["Viewgroup"][(aviva.Viewability < 0.7999999) & (aviva.Viewability > 0.7)] = 0.7
aviva["Viewgroup"][aviva.Viewability > 0.8] = 0.8

# %% [markdown]
# ---

# %%
sns.lmplot(data=aviva, x="Viewability", y="vCPQ", hue="Targeting", row="Targeting", col="Recency", order=2, 
           sharey=False, col_order=["Others", "48 hours", "24 hours", "10 mins"], 
          row_order=["Homepage", "Car homepage", "Start quote", "End quote"])

# %%
sns.lmplot(data=aviva, x="Viewgroup", y="vCPQ", hue="Targeting", row="Targeting", col="Recency", order=2, 
           sharey=False, col_order=["Others", "48 hours", "24 hours", "10 mins"], 
          row_order=["Homepage", "Car homepage", "Start quote", "End quote"])

# %%
sns.fac
